# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/2022-ipl-auction-dataset/ipl-2022-auction-dataset.ipynb

# %% [markdown]
# # Initialising the URL

# %%
url="https://www.news18.com/cricketnext/ipl-auction-2022/mi-players-list-8/"

# %% [markdown]
# # Reading the URL using real_html()

# %%
initial=pd.read_html(url)

# %%
initial
# Out:
# [    #           Player | Squad Base Price          TYPE  COST IN ₹ (CR.)  \
#  0   1        Ishan Kishan | MI       2 Cr  WICKETKEEPER            15.25
#  1   2      Deepak Chahar | CSK       2 Cr        BOWLER            14.00
#  2   3       Shreyas Iyer | KKR       2 Cr        BATTER            12.25
#  3   4  Liam Livingstone | PBKS       1 Cr   ALL-ROUNDER            11.50
#  4   5      Harshal Patel | RCB       2 Cr   ALL-ROUNDER            10.75
#  5   6  Wanindu Hasaranga | RCB       1 Cr   ALL-ROUNDER            10.75
#  6   7    Nicholas Pooran | SRH     1.5 Cr  WICKETKEEPER            10.75
#  7   8      Shardul Thakur | DC       2 Cr        BOWLER            10.75
#  8   9     Prasidh Krishna | RR       1 Cr        BOWLER            10.00
#  9  10         Avesh Khan | LSG    20 Lakh        BOWLER            10.00
#
#     Cost IN $ (000) 2021 Squad
#  0           1982.5         MI
#  1           1820.0        CSK
#  2           1592.5         DC
# ...

# %% [markdown]
# # Creating Gujarat Titans Dataframe

# %%
initial[1]
# Out:
#           2022 Squad GT  Base Price          TYPE  COST IN ₹ (CR.)  \
# 0           Rashid Khan  Draft Pick        BOWLER            15.00
# 1         Hardik Pandya  Draft Pick   ALL-ROUNDER            15.00
# 2       Lockie Ferguson        2 Cr        BOWLER            10.00
# 3         Rahul Tewatia     40 Lakh   ALL-ROUNDER             9.00
# 4          Shubman Gill  Draft Pick        BATTER             8.00
# 5        Mohammad Shami        2 Cr        BOWLER             6.25
# 6            Yash Dayal     20 Lakh        BOWLER             3.20
# 7          David Miller        1 Cr        BATTER             3.00
# 8        R. Sai Kishore     20 Lakh        BOWLER             3.00
# 9   Abhinav Sadarangani     20 Lakh        BATTER             2.60
# 10         Matthew Wade        2 Cr  WICKETKEEPER             2.40
# 11       Alzarri Joseph     75 Lakh        BOWLER             2.40
# 12            Jason Roy        2 Cr        BATTER             2.00
# ...

# %%
gujarat_titans=initial[1]

# %%
gujarat_titans["Team"]="Gujarat Titans"

# %%
gujarat_titans.rename(columns={"2022 Squad GT":"Player"},inplace=True)

# %%
gujarat_titans
# Out:
#                  Player  Base Price          TYPE  COST IN ₹ (CR.)  \
# 0           Rashid Khan  Draft Pick        BOWLER            15.00
# 1         Hardik Pandya  Draft Pick   ALL-ROUNDER            15.00
# 2       Lockie Ferguson        2 Cr        BOWLER            10.00
# 3         Rahul Tewatia     40 Lakh   ALL-ROUNDER             9.00
# 4          Shubman Gill  Draft Pick        BATTER             8.00
# 5        Mohammad Shami        2 Cr        BOWLER             6.25
# 6            Yash Dayal     20 Lakh        BOWLER             3.20
# 7          David Miller        1 Cr        BATTER             3.00
# 8        R. Sai Kishore     20 Lakh        BOWLER             3.00
# 9   Abhinav Sadarangani     20 Lakh        BATTER             2.60
# 10         Matthew Wade        2 Cr  WICKETKEEPER             2.40
# 11       Alzarri Joseph     75 Lakh        BOWLER             2.40
# 12            Jason Roy        2 Cr        BATTER             2.00
# ...

# %% [markdown]
# # Creating Chennai Super Kings Dataframe

# %%
initial[2]
# Out:
#             2022 Squad CSK Base Price          TYPE  COST IN ₹ (CR.)  \
# 0          Ravindra Jadeja   Retained   ALL-ROUNDER            16.00
# 1            Deepak Chahar       2 Cr        BOWLER            14.00
# 2                 MS Dhoni   Retained  WICKETKEEPER            12.00
# 3                Moeen Ali   Retained   ALL-ROUNDER             8.00
# 4            Ambati Rayudu       2 Cr  WICKETKEEPER             6.75
# 5          Ruturaj Gaikwad   Retained        BATTER             6.00
# 6             Dwayne Bravo       2 Cr   ALL-ROUNDER             4.40
# 7              Shivam Dube    50 Lakh   ALL-ROUNDER             4.00
# 8             Chris Jordan       2 Cr   ALL-ROUNDER             3.60
# 9            Robin Uthappa       2 Cr        BATTER             2.00
# 10        Mitchell Santner       1 Cr   ALL-ROUNDER             1.90
# 11              Adam Milne     1.5 Cr        BOWLER             1.90
# 12  Rajvardhan Hangargekar    30 Lakh   ALL-ROUNDER             1.50
# ...

# %%
csk=initial[2]
csk["Team"]="Chennai Super Kings"
csk.rename(columns={"2022 Squad CSK":"Player"},inplace=True)
#Appending into 1 Dataframe
final=gujarat_titans.append(csk,ignore_index=True)
final
# Out:
#                     Player  Base Price          TYPE  COST IN ₹ (CR.)  \
# 0              Rashid Khan  Draft Pick        BOWLER            15.00
# 1            Hardik Pandya  Draft Pick   ALL-ROUNDER            15.00
# 2          Lockie Ferguson        2 Cr        BOWLER            10.00
# 3            Rahul Tewatia     40 Lakh   ALL-ROUNDER             9.00
# 4             Shubman Gill  Draft Pick        BATTER             8.00
# 5           Mohammad Shami        2 Cr        BOWLER             6.25
# 6               Yash Dayal     20 Lakh        BOWLER             3.20
# 7             David Miller        1 Cr        BATTER             3.00
# 8           R. Sai Kishore     20 Lakh        BOWLER             3.00
# 9      Abhinav Sadarangani     20 Lakh        BATTER             2.60
# 10            Matthew Wade        2 Cr  WICKETKEEPER             2.40
# 11          Alzarri Joseph     75 Lakh        BOWLER             2.40
# ...

# %% [markdown]
# # Creating Delhi Capitals Dataframe

# %%
initial[3]
# Out:
#          2022 Squad DC Base Price          TYPE  COST IN ₹ (CR.)  \
# 0         Rishabh Pant   Retained  WICKETKEEPER            16.00
# 1       Shardul Thakur       2 Cr        BOWLER            10.75
# 2           Axar Patel   Retained   ALL-ROUNDER             9.00
# 3         Prithvi Shaw   Retained        BATTER             7.50
# 4       Mitchell Marsh       2 Cr   ALL-ROUNDER             6.50
# 5        Anrich Nortje   Retained        BOWLER             6.50
# 6         David Warner       2 Cr        BATTER             6.25
# 7   Syed Khaleel Ahmed    50 Lakh        BOWLER             5.25
# 8      Chetan Sakariya    50 Lakh        BOWLER             4.20
# 9        Rovman Powell    75 Lakh        BATTER             2.80
# 10         K.S. Bharat    20 Lakh  WICKETKEEPER             2.00
# 11   Mustafizur Rahman       2 Cr        BOWLER             2.00
# 12       Kuldeep Yadav       1 Cr        BOWLER             2.00
# ...

# %%
dc=initial[3]
dc["Team"]="Delhi Capitals"
dc.rename(columns={"2022 Squad DC":"Player"},inplace=True)
#Appending into 1 Dataframe
final=final.append(dc,ignore_index=True)
final
# Out:
#              Player  Base Price         TYPE  COST IN ₹ (CR.)  \
# 0       Rashid Khan  Draft Pick       BOWLER             15.0
# 1     Hardik Pandya  Draft Pick  ALL-ROUNDER             15.0
# 2   Lockie Ferguson        2 Cr       BOWLER             10.0
# 3     Rahul Tewatia     40 Lakh  ALL-ROUNDER              9.0
# 4      Shubman Gill  Draft Pick       BATTER              8.0
# ..              ...         ...          ...              ...
# 66       Yash Dhull     20 Lakh  ALL-ROUNDER              0.5
# 67    Ashwin Hebbar     20 Lakh       BATTER              0.2
# 68    Sarfaraz Khan     20 Lakh  ALL-ROUNDER              0.2
# 69      Ripal Patel     20 Lakh  ALL-ROUNDER              0.2
# 70     Vicky Ostwal     20 Lakh  ALL-ROUNDER              0.2
#
#     Cost IN $ (000) 2021 Squad            Team
# 0            1950.0        SRH  Gujarat Titans
# 1            1950.0         MI  Gujarat Titans
# 2            1300.0        KKR  Gujarat Titans
# ...

# %% [markdown]
# # Creating Kolkata Knight Riders Dataframe

# %%
initial[4]
# Out:
#          2022 Squad KKR Base Price          TYPE  COST IN ₹ (CR.)  \
# 0          Shreyas Iyer       2 Cr        BATTER            12.25
# 1         Andre Russell   Retained   ALL-ROUNDER            12.00
# 2           Nitish Rana       1 Cr   ALL-ROUNDER             8.00
# 3        Venkatesh Iyer   Retained   ALL-ROUNDER             8.00
# 4   Varun Chakaravarthy   Retained        BOWLER             8.00
# 5           Pat Cummins       2 Cr   ALL-ROUNDER             7.25
# 6           Shivam Mavi    40 Lakh   ALL-ROUNDER             7.25
# 7          Sunil Narine   Retained   ALL-ROUNDER             6.00
# 8          Sam Billings       2 Cr  WICKETKEEPER             2.00
# 9           Umesh Yadav       2 Cr        BOWLER             2.00
# 10          Tim Southee     1.5 Cr        BOWLER             1.50
# 11           Alex Hales     1.5 Cr        BATTER             1.50
# 12       Ajinkya Rahane       1 Cr        BATTER             1.00
# ...

# %%
kkr=initial[4]
kkr["Team"]="Kolkata Knight Riders"
kkr.rename(columns={"2022 Squad KKR":"Player"},inplace=True)
#Appending into 1 Dataframe
final=final.append(kkr,ignore_index=True)
final
# Out:
#              Player  Base Price          TYPE  COST IN ₹ (CR.)  \
# 0       Rashid Khan  Draft Pick        BOWLER             15.0
# 1     Hardik Pandya  Draft Pick   ALL-ROUNDER             15.0
# 2   Lockie Ferguson        2 Cr        BOWLER             10.0
# 3     Rahul Tewatia     40 Lakh   ALL-ROUNDER              9.0
# 4      Shubman Gill  Draft Pick        BATTER              8.0
# ..              ...         ...           ...              ...
# 91       Anukul Roy     20 Lakh   ALL-ROUNDER              0.2
# 92   Baba Indrajith     20 Lakh  WICKETKEEPER              0.2
# 93        Aman Khan     20 Lakh   ALL-ROUNDER              0.2
# 94     Ramesh Kumar     20 Lakh        BATTER              0.2
# 95    Pratham Singh     20 Lakh        BATTER              0.2
#
#     Cost IN $ (000) 2021 Squad                   Team
# 0            1950.0        SRH         Gujarat Titans
# 1            1950.0         MI         Gujarat Titans
# ...

# %% [markdown]
# # Creating Punjab Kings Dataframe

# %%
initial[5]
# Out:
#         2022 Squad PBKS Base Price          TYPE  COST IN ₹ (CR.)  \
# 0        Mayank Agarwal   Retained        BATTER            12.00
# 1      Liam Livingstone       1 Cr   ALL-ROUNDER            11.50
# 2         Kagiso Rabada       2 Cr        BOWLER             9.25
# 3         Shahrukh Khan    40 Lakh   ALL-ROUNDER             9.00
# 4        Shikhar Dhawan       2 Cr        BATTER             8.25
# 5        Jonny Bairstow     1.5 Cr  WICKETKEEPER             6.75
# 6           Odean Smith       1 Cr   ALL-ROUNDER             6.00
# 7          Rahul Chahar    75 Lakh        BOWLER             5.25
# 8        Arshdeep Singh   Retained        BOWLER             4.00
# 9         Harpreet Brar    20 Lakh   ALL-ROUNDER             3.80
# 10        Vaibhav Arora    20 Lakh        BOWLER             2.00
# 11       Raj Angad Bawa    20 Lakh   ALL-ROUNDER             2.00
# 12         Nathan Ellis    75 Lakh        BOWLER             0.75
# ...

# %%
pbks=initial[5]
pbks["Team"]="Punjab Kings"
pbks.rename(columns={"2022 Squad PBKS":"Player"},inplace=True)
#Appending into 1 Dataframe
final=final.append(pbks,ignore_index=True)
final
# Out:
#                   Player  Base Price          TYPE  COST IN ₹ (CR.)  \
# 0            Rashid Khan  Draft Pick        BOWLER             15.0
# 1          Hardik Pandya  Draft Pick   ALL-ROUNDER             15.0
# 2        Lockie Ferguson        2 Cr        BOWLER             10.0
# 3          Rahul Tewatia     40 Lakh   ALL-ROUNDER              9.0
# 4           Shubman Gill  Draft Pick        BATTER              8.0
# ..                   ...         ...           ...              ...
# 116           Ansh Patel     20 Lakh   ALL-ROUNDER              0.2
# 117        Jitesh Sharma     20 Lakh  WICKETKEEPER              0.2
# 118  Writtick Chatterjee     20 Lakh   ALL-ROUNDER              0.2
# 119        Atharva Taide     20 Lakh   ALL-ROUNDER              0.2
# 120        Baltej Dhanda     20 Lakh        BOWLER              0.2
#
#      Cost IN $ (000) 2021 Squad            Team
# 0             1950.0        SRH  Gujarat Titans
# 1             1950.0         MI  Gujarat Titans
# ...

# %% [markdown]
# # Creating Lucknow Super Giants Dataframe

# %%
initial[6]
# Out:
#          2022 Squad LSG  Base Price          TYPE  COST IN ₹ (CR.)  \
# 0              KL Rahul  Draft Pick  WICKETKEEPER            17.00
# 1            Avesh Khan     20 Lakh        BOWLER            10.00
# 2        Marcus Stoinis  Draft Pick   ALL-ROUNDER             9.20
# 3          Jason Holder      1.5 Cr   ALL-ROUNDER             8.75
# 4         Krunal Pandya        2 Cr   ALL-ROUNDER             8.25
# 5             Mark Wood        2 Cr        BOWLER             7.50
# 6       Quinton De Kock        2 Cr  WICKETKEEPER             6.75
# 7          Deepak Hooda     75 Lakh   ALL-ROUNDER             5.75
# 8         Manish Pandey        1 Cr        BATTER             4.60
# 9          Ravi Bishnoi  Draft Pick        BOWLER             4.00
# 10   Dushmanta Chameera     50 Lakh        BOWLER             2.00
# 11           Evin Lewis        2 Cr        BATTER             2.00
# 12           K. Gowtham     50 Lakh   ALL-ROUNDER             0.90
# ...

# %%
lsg=initial[6]
lsg["Team"]="Lucknow Super Giants"
lsg.rename(columns={"2022 Squad LSG":"Player"},inplace=True)
#Appending into 1 Dataframe
final=final.append(lsg,ignore_index=True)
final
# Out:
#                Player  Base Price         TYPE  COST IN ₹ (CR.)  \
# 0         Rashid Khan  Draft Pick       BOWLER             15.0
# 1       Hardik Pandya  Draft Pick  ALL-ROUNDER             15.0
# 2     Lockie Ferguson        2 Cr       BOWLER             10.0
# 3       Rahul Tewatia     40 Lakh  ALL-ROUNDER              9.0
# 4        Shubman Gill  Draft Pick       BATTER              8.0
# ..                ...         ...          ...              ...
# 138  B. Sai Sudharsan     20 Lakh  ALL-ROUNDER              0.2
# 139      Karan Sharma     20 Lakh  ALL-ROUNDER              0.2
# 140      Ayush Badoni     20 Lakh  ALL-ROUNDER              0.2
# 141       Mohsin Khan     20 Lakh       BOWLER              0.2
# 142      Mayank Yadav     20 Lakh       BOWLER              0.2
#
#      Cost IN $ (000) 2021 Squad                  Team
# 0             1950.0        SRH        Gujarat Titans
# 1             1950.0         MI        Gujarat Titans
# ...

# %% [markdown]
# # Creating Mumbai Indians Dataframe

# %%
initial[7]
# Out:
#         2022 Squad MI Base Price          TYPE  COST IN ₹ (CR.)  \
# 0        Rohit Sharma   Retained        BATTER            16.00
# 1        Ishan Kishan       2 Cr  WICKETKEEPER            15.25
# 2      Jasprit Bumrah   Retained        BOWLER            12.00
# 3           Tim David    40 Lakh   ALL-ROUNDER             8.25
# 4        Jofra Archer       2 Cr   ALL-ROUNDER             8.00
# 5    Suryakumar Yadav   Retained        BATTER             8.00
# 6      Kieron Pollard   Retained   ALL-ROUNDER             6.00
# 7       Dewald Brevis    20 Lakh        BATTER             3.00
# 8         Daniel Sams       1 Cr   ALL-ROUNDER             2.60
# 9      N. Tilak Varma    20 Lakh   ALL-ROUNDER             1.70
# 10     Murugan Ashwin    20 Lakh        BOWLER             1.60
# 11        Tymal Mills       1 Cr        BOWLER             1.50
# 12     Jaydev Unadkat    75 Lakh        BOWLER             1.30
# 13     Riley Meredith       1 Cr        BOWLER             1.00
# ...

# %%
mi=initial[7]
mi["Team"]="Mumbai Indians"
mi.rename(columns={"2022 Squad MI":"Player"},inplace=True)
#Appending into 1 Dataframe
final=final.append(mi,ignore_index=True)
final
# Out:
#                 Player  Base Price          TYPE  COST IN ₹ (CR.)  \
# 0          Rashid Khan  Draft Pick        BOWLER             15.0
# 1        Hardik Pandya  Draft Pick   ALL-ROUNDER             15.0
# 2      Lockie Ferguson        2 Cr        BOWLER             10.0
# 3        Rahul Tewatia     40 Lakh   ALL-ROUNDER              9.0
# 4         Shubman Gill  Draft Pick        BATTER              8.0
# ..                 ...         ...           ...              ...
# 163        Aryan Juyal     20 Lakh  WICKETKEEPER              0.2
# 164    Ramandeep Singh     20 Lakh   ALL-ROUNDER              0.2
# 165       Rahul Buddhi     20 Lakh        BATTER              0.2
# 166    Hrithik Shokeen     20 Lakh   ALL-ROUNDER              0.2
# 167  Mohd. Arshad Khan     20 Lakh   ALL-ROUNDER              0.2
#
#      Cost IN $ (000) 2021 Squad            Team
# 0             1950.0        SRH  Gujarat Titans
# 1             1950.0         MI  Gujarat Titans
# ...

# %% [markdown]
# # Creating Royal Challengers Bangalore Dataframe

# %%
initial[8]
# Out:
#          2022 Squad RCB Base Price          TYPE  COST IN ₹ (CR.)  \
# 0           Virat Kohli   Retained        BATTER            15.00
# 1         Glenn Maxwell   Retained   ALL-ROUNDER            11.00
# 2     Wanindu Hasaranga       1 Cr   ALL-ROUNDER            10.75
# 3         Harshal Patel       2 Cr   ALL-ROUNDER            10.75
# 4        Josh Hazlewood       2 Cr        BOWLER             7.75
# 5        Faf Du Plessis       2 Cr        BATTER             7.00
# 6        Mohammed Siraj   Retained        BOWLER             7.00
# 7        Dinesh Karthik       2 Cr  WICKETKEEPER             5.50
# 8            Anuj Rawat    20 Lakh  WICKETKEEPER             3.40
# 9        Shahbaz Ahamad    30 Lakh   ALL-ROUNDER             2.40
# 10         David Willey       2 Cr   ALL-ROUNDER             2.00
# 11  Sherfane Rutherford       1 Cr   ALL-ROUNDER             1.00
# 12       Mahipal Lomror    40 Lakh   ALL-ROUNDER             0.95
# ...

# %%
rcb=initial[8]
rcb["Team"]="Royal Challengers Bangalore"
rcb.rename(columns={"2022 Squad RCB":"Player"},inplace=True)
#Appending into 1 Dataframe
final=final.append(rcb,ignore_index=True)
final
# Out:
#                   Player  Base Price          TYPE  COST IN ₹ (CR.)  \
# 0            Rashid Khan  Draft Pick        BOWLER            15.00
# 1          Hardik Pandya  Draft Pick   ALL-ROUNDER            15.00
# 2        Lockie Ferguson        2 Cr        BOWLER            10.00
# 3          Rahul Tewatia     40 Lakh   ALL-ROUNDER             9.00
# 4           Shubman Gill  Draft Pick        BATTER             8.00
# ..                   ...         ...           ...              ...
# 185  Suyash Prabhudessai     20 Lakh   ALL-ROUNDER             0.30
# 186         Chama Milind     20 Lakh        BOWLER             0.25
# 187           Akash Deep     20 Lakh        BOWLER             0.20
# 188     Aneeshwar Gautam     20 Lakh   ALL-ROUNDER             0.20
# 189      Luvnith Sisodia     20 Lakh  WICKETKEEPER             0.20
#
#      Cost IN $ (000) 2021 Squad                         Team
# 0             1950.0        SRH               Gujarat Titans
# ...

# %% [markdown]
# # Creating Rajasthan Royals Dataframe

# %%
initial[9]
# Out:
#             2022 Squad RR Base Price          TYPE  COST IN ₹ (CR.)  \
# 0            Sanju Samson   Retained  WICKETKEEPER            14.00
# 1             Jos Buttler   Retained  WICKETKEEPER            10.00
# 2         Prasidh Krishna       1 Cr        BOWLER            10.00
# 3         Shimron Hetmyer     1.5 Cr        BATTER             8.50
# 4             Trent Boult       2 Cr        BOWLER             8.00
# 5        Devdutt Padikkal       2 Cr        BATTER             7.75
# 6        Yuzvendra Chahal       2 Cr        BOWLER             6.50
# 7               R. Ashwin       2 Cr   ALL-ROUNDER             5.00
# 8        Yashaswi Jaiswal   Retained        BATTER             4.00
# 9             Riyan Parag    30 Lakh   ALL-ROUNDER             3.80
# 10          Navdeep Saini    75 Lakh        BOWLER             2.60
# 11    Nathan Coulter-Nile       2 Cr        BOWLER             2.00
# 12          James Neesham     1.5 Cr   ALL-ROUNDER             1.50
# ...

# %%
rr=initial[9]
rr["Team"]="Rajasthan Royals"
rr.rename(columns={"2022 Squad RR":"Player"},inplace=True)
#Appending into 1 Dataframe
final=final.append(rr,ignore_index=True)
final
# Out:
#               Player  Base Price          TYPE  COST IN ₹ (CR.)  \
# 0        Rashid Khan  Draft Pick        BOWLER             15.0
# 1      Hardik Pandya  Draft Pick   ALL-ROUNDER             15.0
# 2    Lockie Ferguson        2 Cr        BOWLER             10.0
# 3      Rahul Tewatia     40 Lakh   ALL-ROUNDER              9.0
# 4       Shubman Gill  Draft Pick        BATTER              8.0
# ..               ...         ...           ...              ...
# 209      Kuldeep Sen     20 Lakh        BOWLER              0.2
# 210      Dhruv Jurel     20 Lakh  WICKETKEEPER              0.2
# 211     Tejas Baroka     20 Lakh        BOWLER              0.2
# 212     Kuldip Yadav     20 Lakh        BOWLER              0.2
# 213  Shubham Garhwal     20 Lakh   ALL-ROUNDER              0.2
#
#      Cost IN $ (000) 2021 Squad              Team
# 0             1950.0        SRH    Gujarat Titans
# 1             1950.0         MI    Gujarat Titans
# ...

# %% [markdown]
# # Creating Sunrisers Hyderabad Dataframe

# %%
initial[10]
# Out:
#         2022 Squad SRH Base Price          TYPE  COST IN ₹ (CR.)  \
# 0      Kane Williamson   Retained        BATTER            14.00
# 1      Nicholas Pooran     1.5 Cr  WICKETKEEPER            10.75
# 2    Washington Sundar     1.5 Cr   ALL-ROUNDER             8.75
# 3       Rahul Tripathi    40 Lakh        BATTER             8.50
# 4     Romario Shepherd    75 Lakh   ALL-ROUNDER             7.75
# 5      Abhishek Sharma    20 Lakh   ALL-ROUNDER             6.50
# 6         Marco Jansen    50 Lakh   ALL-ROUNDER             4.20
# 7    Bhuvneshwar Kumar       2 Cr        BOWLER             4.20
# 8         T. Natarajan       1 Cr        BOWLER             4.00
# 9          Abdul Samad   Retained   ALL-ROUNDER             4.00
# 10         Umran Malik   Retained        BOWLER             4.00
# 11        Kartik Tyagi    20 Lakh        BOWLER             4.00
# 12       Aiden Markram       1 Cr        BATTER             2.60
# ...

# %%
srh=initial[10]
srh["Team"]="Sunrisers Hyderabad"
srh.rename(columns={"2022 Squad SRH":"Player"},inplace=True)
#Appending into 1 Dataframe
final=final.append(srh,ignore_index=True)
final
# Out:
#                  Player  Base Price         TYPE  COST IN ₹ (CR.)  \
# 0           Rashid Khan  Draft Pick       BOWLER             15.0
# 1         Hardik Pandya  Draft Pick  ALL-ROUNDER             15.0
# 2       Lockie Ferguson        2 Cr       BOWLER             10.0
# 3         Rahul Tewatia     40 Lakh  ALL-ROUNDER              9.0
# 4          Shubman Gill  Draft Pick       BATTER              8.0
# ..                  ...         ...          ...              ...
# 232         Priyam Garg     20 Lakh       BATTER              0.2
# 233           R Samarth     20 Lakh       BATTER              0.2
# 234  Jagadeesha Suchith     20 Lakh       BOWLER              0.2
# 235      Shashank Singh     20 Lakh  ALL-ROUNDER              0.2
# 236       Saurabh Dubey     20 Lakh       BOWLER              0.2
#
#      Cost IN $ (000) 2021 Squad                 Team
# 0             1950.0        SRH       Gujarat Titans
# 1             1950.0         MI       Gujarat Titans
# ...

# %% [markdown]
# # Adding Information of Unsold Players

# %%
initial[11]
# Out:
#                     Players         TYPE Base Price IN ₹ (CR.)  \
# 0              Suresh Raina       BATTER                  2 Cr
# 1               Steve Smith       BATTER                  2 Cr
# 2           Shakib Al Hasan  ALL-ROUNDER                  2 Cr
# 3               Amit Mishra       BOWLER                1.5 Cr
# 4               Adil Rashid       BOWLER                  2 Cr
# ..                      ...          ...                   ...
# 391            Sairaj Patil       BATTER               20 Lakh
# 392              Monu Singh       BOWLER               20 Lakh
# 393  Nivethan Radhakrishnan       BOWLER               20 Lakh
# 394            Lance Morris       BOWLER               20 Lakh
# 395            Aaron Hardie  ALL-ROUNDER               20 Lakh
#
#      Base Price IN $ (000) 2021 Squad
# 0                      NaN        CSK
# 1                      NaN         DC
# 2                      NaN        KKR
# 3                      NaN         DC
# ...

# %%
test=initial[11]

# %% [markdown]
# # Making Changes to append
# We need to make some changes to this dataframe in order to append to the final dataframe

# %%
#rename as same as final dataframe
test.rename(columns={"Base Price IN ₹ (CR.)":"Base Price"},inplace=True)

# %%
#rename as same as final dataframe
test.rename(columns={"Players":"Player"},inplace=True)

# %%
#dropping unwanted column
test.drop("Base Price IN $ (000)",axis=1,inplace=True)

# %%
#creating new columns with null values as same as final dataframe
test["COST IN ₹ (CR.)"]= np.nan

# %%
#creating new columns with null values as same as final dataframe
test["Cost IN $ (000)"]= np.nan

# %%
#Adding Team name as Unsold
test["Team"]="Unsold"

# %%
final
# Out:
#                  Player  Base Price         TYPE  COST IN ₹ (CR.)  \
# 0           Rashid Khan  Draft Pick       BOWLER             15.0
# 1         Hardik Pandya  Draft Pick  ALL-ROUNDER             15.0
# 2       Lockie Ferguson        2 Cr       BOWLER             10.0
# 3         Rahul Tewatia     40 Lakh  ALL-ROUNDER              9.0
# 4          Shubman Gill  Draft Pick       BATTER              8.0
# ..                  ...         ...          ...              ...
# 232         Priyam Garg     20 Lakh       BATTER              0.2
# 233           R Samarth     20 Lakh       BATTER              0.2
# 234  Jagadeesha Suchith     20 Lakh       BOWLER              0.2
# 235      Shashank Singh     20 Lakh  ALL-ROUNDER              0.2
# 236       Saurabh Dubey     20 Lakh       BOWLER              0.2
#
#      Cost IN $ (000) 2021 Squad                 Team
# 0             1950.0        SRH       Gujarat Titans
# 1             1950.0         MI       Gujarat Titans
# ...

# %%
final.columns
# Out:
# Index(['Player', 'Base Price', 'TYPE', 'COST IN ₹ (CR.)', 'Cost IN $ (000)',
#        '2021 Squad', 'Team'],
#       dtype='object')

# %%
#reordering the columns as same as final dataframe
test=test[['Player','Base Price', 'TYPE', 'COST IN ₹ (CR.)', 'Cost IN $ (000)','2021 Squad', 'Team']]

# %%
final=final.append(test,ignore_index=True)

# %%
final
# Out:
#                      Player  Base Price         TYPE  COST IN ₹ (CR.)  \
# 0               Rashid Khan  Draft Pick       BOWLER             15.0
# 1             Hardik Pandya  Draft Pick  ALL-ROUNDER             15.0
# 2           Lockie Ferguson        2 Cr       BOWLER             10.0
# 3             Rahul Tewatia     40 Lakh  ALL-ROUNDER              9.0
# 4              Shubman Gill  Draft Pick       BATTER              8.0
# ..                      ...         ...          ...              ...
# 628            Sairaj Patil     20 Lakh       BATTER              NaN
# 629              Monu Singh     20 Lakh       BOWLER              NaN
# 630  Nivethan Radhakrishnan     20 Lakh       BOWLER              NaN
# 631            Lance Morris     20 Lakh       BOWLER              NaN
# 632            Aaron Hardie     20 Lakh  ALL-ROUNDER              NaN
#
#      Cost IN $ (000) 2021 Squad            Team
# 0             1950.0        SRH  Gujarat Titans
# ...

# %% [markdown]
# # Exporting the final Dataframe as CSV file

# %%
final.to_csv("ipl_2022_dataset.csv")
