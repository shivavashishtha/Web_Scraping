# %% [markdown]
# # Big Bang Theory All Seasons Dataset

# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/big-bang-theory-all-seasons-dataset/dataset.csv

# %%
#fetching the data using read_html
data=pd.read_html("https://en.wikipedia.org/wiki/List_of_The_Big_Bang_Theory_episodes")

# %%
#printing the fetched data
data
# Out:
# [   Season          Episodes               Originally aired                \
#     Season Season.1 Episodes Episodes.1         First aired    Last aired
#  0     NaN        1       17         17  September 24, 2007  May 19, 2008
#  1     NaN        2       23         23  September 22, 2008  May 11, 2009
#  2     NaN        3       23         23  September 21, 2009  May 24, 2010
#  3     NaN        4       24         24  September 23, 2010  May 19, 2011
#  4     NaN        5       24         24  September 22, 2011  May 10, 2012
#  5     NaN        6       24         24  September 27, 2012  May 16, 2013
#  6     NaN        7       24         24  September 26, 2013  May 15, 2014
#  7     NaN        8       24         24  September 22, 2014   May 7, 2015
#  8     NaN        9       24         24  September 21, 2015  May 12, 2016
#  9     NaN       10       24         24  September 19, 2016  May 11, 2017
#  10    NaN       11       24         24  September 25, 2017  May 10, 2018
# ...

# %%
#checking the type of data
type(data)
#As the data is a list we'll be using indexing to get the data from this list
# Out:
# list

# %%
data[0]
#At index Zero we have info about all the seasons
# Out:
#    Season          Episodes               Originally aired                \
#    Season Season.1 Episodes Episodes.1         First aired    Last aired
# 0     NaN        1       17         17  September 24, 2007  May 19, 2008
# 1     NaN        2       23         23  September 22, 2008  May 11, 2009
# 2     NaN        3       23         23  September 21, 2009  May 24, 2010
# 3     NaN        4       24         24  September 23, 2010  May 19, 2011
# 4     NaN        5       24         24  September 22, 2011  May 10, 2012
# 5     NaN        6       24         24  September 27, 2012  May 16, 2013
# 6     NaN        7       24         24  September 26, 2013  May 15, 2014
# 7     NaN        8       24         24  September 22, 2014   May 7, 2015
# 8     NaN        9       24         24  September 21, 2015  May 12, 2016
# 9     NaN       10       24         24  September 19, 2016  May 11, 2017
# 10    NaN       11       24         24  September 25, 2017  May 10, 2018
# ...

# %%
data[1]
#At index 1 we have the dataframe containing data of season 1
# Out:
#     No.overall  No. inseason  \
# 0            1             1
# 1            2             2
# 2            3             3
# 3            4             4
# 4            5             5
# 5            6             6
# 6            7             7
# 7            8             8
# 8            9             9
# 9           10            10
# 10          11            11
# 11          12            12
# 12          13            13
# 13          14            14
# 14          15            15
# 15          16            16
# 16          17            17
#
#                                                 Title       Directed by  \
# 0                                             "Pilot"     James Burrows
# 1                           "The Big Bran Hypothesis"   Mark Cendrowski
# 2                         "The Fuzzy Boots Corollary"   Mark Cendrowski
# 3                          "The Luminous Fish Effect"   Mark Cendrowski
# ...

# %%
s1=data[1]

# %%
s1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17 entries, 0 to 16
# Data columns (total 8 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   No.overall              17 non-null     int64
#  1   No. inseason            17 non-null     int64
#  2   Title                   17 non-null     object
#  3   Directed by             17 non-null     object
#  4   Written by              17 non-null     object
#  5   Original air date       17 non-null     object
#  6   Prod.code               17 non-null     object
#  7   U.S. viewers(millions)  17 non-null     object
# dtypes: int64(2), object(6)
# memory usage: 1.2+ KB

# %%
s1.columns
# Out:
# Index(['No.overall', 'No. inseason', 'Title', 'Directed by', 'Written by',
#        'Original air date', 'Prod.code', 'U.S. viewers(millions)'],
#       dtype='object')

# %% [markdown]
# #

# %%
#slicing the views number and changing the type to float
s1["U.S. viewers(millions)"]=s1["U.S. viewers(millions)"].str.slice(start=0,stop=4)
s1["U.S. viewers(millions)"] = s1["U.S. viewers(millions)"].astype("float")

# %%
#adiing a new column for defining season number
s1["Season"]=1

# %%
s1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17 entries, 0 to 16
# Data columns (total 9 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   No.overall              17 non-null     int64
#  1   No. inseason            17 non-null     int64
#  2   Title                   17 non-null     object
#  3   Directed by             17 non-null     object
#  4   Written by              17 non-null     object
#  5   Original air date       17 non-null     object
#  6   Prod.code               17 non-null     object
#  7   U.S. viewers(millions)  17 non-null     float64
#  8   Season                  17 non-null     int64
# dtypes: float64(1), int64(3), object(5)
# memory usage: 1.3+ KB

# %%
s1.columns
# Out:
# Index(['No.overall', 'No. inseason', 'Title', 'Directed by', 'Written by',
#        'Original air date', 'Prod.code', 'U.S. viewers(millions)', 'Season'],
#       dtype='object')

# %%
#changing column type from cstring to datetime
s1["Original air date"] = pd.to_datetime(s1["Original air date"])

# %%
s1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17 entries, 0 to 16
# Data columns (total 9 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   No.overall              17 non-null     int64
#  1   No. inseason            17 non-null     int64
#  2   Title                   17 non-null     object
#  3   Directed by             17 non-null     object
#  4   Written by              17 non-null     object
#  5   Original air date       17 non-null     datetime64[ns]
#  6   Prod.code               17 non-null     object
#  7   U.S. viewers(millions)  17 non-null     float64
#  8   Season                  17 non-null     int64
# dtypes: datetime64[ns](1), float64(1), int64(3), object(4)
# memory usage: 1.3+ KB

# %%
s1
# Out:
#     No.overall  No. inseason  \
# 0            1             1
# 1            2             2
# 2            3             3
# 3            4             4
# 4            5             5
# 5            6             6
# 6            7             7
# 7            8             8
# 8            9             9
# 9           10            10
# 10          11            11
# 11          12            12
# 12          13            13
# 13          14            14
# 14          15            15
# 15          16            16
# 16          17            17
#
#                                                 Title       Directed by  \
# 0                                             "Pilot"     James Burrows
# 1                           "The Big Bran Hypothesis"   Mark Cendrowski
# 2                         "The Fuzzy Boots Corollary"   Mark Cendrowski
# 3                          "The Luminous Fish Effect"   Mark Cendrowski
# ...

# %%
s2=data[2]

# %%
#repeating same steps for season 2
s2["U.S. viewers(millions)"]=s2["U.S. viewers(millions)"].str.slice(start=0,stop=4)
s2["U.S. viewers(millions)"] = s2["U.S. viewers(millions)"].astype("float")
s2["Original air date"] = pd.to_datetime(s2["Original air date"])
s2["Season"]=2

# %%
s2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23 entries, 0 to 22
# Data columns (total 9 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   No.overall              23 non-null     int64
#  1   No. inseason            23 non-null     int64
#  2   Title                   23 non-null     object
#  3   Directed by             23 non-null     object
#  4   Written by              23 non-null     object
#  5   Original air date       23 non-null     datetime64[ns]
#  6   Prod.code               23 non-null     object
#  7   U.S. viewers(millions)  23 non-null     float64
#  8   Season                  23 non-null     int64
# dtypes: datetime64[ns](1), float64(1), int64(3), object(4)
# memory usage: 1.7+ KB

# %%
#creating a new dataframe and appending both the dataframes
final=s1.append(s2,ignore_index=True)

# %%
final
# Out:
#     No.overall  No. inseason  \
# 0            1             1
# 1            2             2
# 2            3             3
# 3            4             4
# 4            5             5
# 5            6             6
# 6            7             7
# 7            8             8
# 8            9             9
# 9           10            10
# 10          11            11
# 11          12            12
# 12          13            13
# 13          14            14
# 14          15            15
# 15          16            16
# 16          17            17
# 17          18             1
# 18          19             2
# 19          20             3
# 20          21             4
# 21          22             5
# 22          23             6
# 23          24             7
# 24          25             8
# 25          26             9
# 26          27            10
# 27          28            11
# 28          29            12
# 29          30            13
# 30          31            14
# ...

# %%
data[3]
# Out:
#     No.overall  No. inseason                                  Title  \
# 0           41             1  "The Electric Can Opener Fluctuation"
# 1           42             2                "The Jiminy Conjecture"
# 2           43             3              "The Gothowitz Deviation"
# 3           44             4                  "The Pirate Solution"
# 4           45             5   "The Creepy Candy Coating Corollary"
# 5           46             6                "The Cornhusker Vortex"
# 6           47             7          "The Guitarist Amplification"
# 7           48             8         "The Adhesive Duck Deficiency"
# 8           49             9            "The Vengeance Formulation"
# 9           50            10               "The Gorilla Experiment"
# 10          51            11              "The Maternal Congruence"
# 11          52            12                   "The Psychic Vortex"
# 12          53            13                 "The Bozeman Reaction"
# ...

# %%
s3=data[3]

# %%
#repeating same steps for season 3
s3["U.S. viewers(millions)"]=s3["U.S. viewers(millions)"].str.slice(start=0,stop=4)
s3["U.S. viewers(millions)"] = s3["U.S. viewers(millions)"].astype("float")
s3["Original air date"] = pd.to_datetime(s3["Original air date"])
s3["Season"]=3
final=final.append(s3,ignore_index=True)
final
# Out:
#     No.overall  No. inseason                           Title  \
# 0            1             1                         "Pilot"
# 1            2             2       "The Big Bran Hypothesis"
# 2            3             3     "The Fuzzy Boots Corollary"
# 3            4             4      "The Luminous Fish Effect"
# 4            5             5       "The Hamburger Postulate"
# ..         ...           ...                             ...
# 58          59            19        "The Wheaton Recurrence"
# 59          60            20        "The Spaghetti Catalyst"
# 60          61            21      "The Plimpton Stimulation"
# 61          62            22  "The Staircase Implementation"
# 62          63            23          "The Lunar Excitation"
#
#          Directed by                                         Written by  \
# 0      James Burrows                           Chuck Lorre & Bill Prady
# 1    Mark Cendrowski  Story by : Chuck Lorre & Bill PradyTeleplay by...
# ...

# %%
data[4]
# Out:
#     No.overall  No. inseason                                      Title  \
# 0           64             1                 "The Robotic Manipulation"
# 1           65             2  "The Cruciferous Vegetable Amplification"
# 2           66             3                   "The Zazzy Substitution"
# 3           67             4                  "The Hot Troll Deviation"
# 4           68             5                "The Desperation Emanation"
# 5           69             6                "The Irish Pub Formulation"
# 6           70             7                "The Apology Insufficiency"
# 7           71             8                 "The 21-Second Excitation"
# 8           72             9                 "The Boyfriend Complexity"
# 9           73            10            "The Alien Parasite Hypothesis"
# 10          74            11         "The Justice League Recombination"
# 11          75            12                "The Bus Pants Utilization"
# ...

# %%
s4=data[4]

# %%
#repeating same steps for season 4
s4["U.S. viewers(millions)"]=s4["U.S. viewers(millions)"].str.slice(start=0,stop=4)
s4["U.S. viewers(millions)"] = s4["U.S. viewers(millions)"].astype("float")
s4["Original air date"] = pd.to_datetime(s4["Original air date"])
s4["Season"]=4
final=final.append(s4,ignore_index=True)
final
# Out:
#     No.overall  No. inseason                              Title  \
# 0            1             1                            "Pilot"
# 1            2             2          "The Big Bran Hypothesis"
# 2            3             3        "The Fuzzy Boots Corollary"
# 3            4             4         "The Luminous Fish Effect"
# 4            5             5          "The Hamburger Postulate"
# ..         ...           ...                                ...
# 82          83            20      "The Herb Garden Germination"
# 83          84            21         "The Agreement Dissection"
# 84          85            22    "The Wildebeest Implementation"
# 85          86            23          "The Engagement Reaction"
# 86          87            24  "The Roommate Transmogrification"
#
#          Directed by                                         Written by  \
# 0      James Burrows                           Chuck Lorre & Bill Prady
# ...

# %%
data[5]
# Out:
#     No.overall  No. inseason                               Title  \
# 0           88             1         "The Skank Reflex Analysis"
# 1           89             2        "The Infestation Hypothesis"
# 2           90             3    "The Pulled Groin Extrapolation"
# 3           91             4        "The Wiggly Finger Catalyst"
# 4           92             5       "The Russian Rocket Reaction"
# 5           93             6           "The Rhinitis Revelation"
# 6           94             7          "The Good Guy Fluctuation"
# 7           95             8         "The Isolation Permutation"
# 8           96             9       "The Ornithophobia Diffusion"
# 9           97            10  "The Flaming Spittoon Acquisition"
# 10          98            11         "The Speckerman Recurrence"
# 11          99            12        "The Shiny Trinket Maneuver"
# 12         100            13      "The Recombination Hypothesis"
# ...

# %%
s5=data[5]

# %%
#repeating same steps for season 5
s5["U.S. viewers(millions)"]=s5["U.S. viewers(millions)"].str.slice(start=0,stop=4)
s5["U.S. viewers(millions)"] = s5["U.S. viewers(millions)"].astype("float")
s5["Original air date"] = pd.to_datetime(s5["Original air date"])
s5["Season"]=5
final=final.append(s5,ignore_index=True)
final
# Out:
#      No.overall  No. inseason                          Title  \
# 0             1             1                        "Pilot"
# 1             2             2      "The Big Bran Hypothesis"
# 2             3             3    "The Fuzzy Boots Corollary"
# 3             4             4     "The Luminous Fish Effect"
# 4             5             5      "The Hamburger Postulate"
# ..          ...           ...                            ...
# 106         107            20  "The Transporter Malfunction"
# 107         108            21       "The Hawking Excitation"
# 108         109            22         "The Stag Convergence"
# 109         110            23      "The Launch Acceleration"
# 110         111            24     "The Countdown Reflection"
#
#           Directed by                                         Written by  \
# 0       James Burrows                           Chuck Lorre & Bill Prady
# 1     Mark Cendrowski  Story by : Chuck Lorre & Bill PradyTeleplay by...
# ...

# %%
data[6]
# Out:
#     No.overall  No. inseason                                        Title  \
# 0          112             1                    "The Date Night Variable"
# 1          113             2                 "The Decoupling Fluctuation"
# 2          114             3                "The Higgs Boson Observation"
# 3          115             4                  "The Re-Entry Minimization"
# 4          116             5                 "The Holographic Excitation"
# 5          117             6                   "The Extract Obliteration"
# 6          118             7               "The Habitation Configuration"
# 7          119             8                         "The 43 Peculiarity"
# 8          120             9                "The Parking Spot Escalation"
# 9          121            10                 "The Fish Guts Displacement"
# 10         122            11                       "The Santa Simulation"
# 11         123            12                  "The Egg Salad Equivalency"
# ...

# %%
s6=data[6]

# %%
#repeating same steps for season 6
s6["U.S. viewers(millions)"]=s6["U.S. viewers(millions)"].str.slice(start=0,stop=4)
s6["U.S. viewers(millions)"] = s6["U.S. viewers(millions)"].astype("float")
s6["Original air date"] = pd.to_datetime(s6["Original air date"])
s6["Season"]=6
final=final.append(s6,ignore_index=True)
final
# Out:
#      No.overall  No. inseason                        Title       Directed by  \
# 0             1             1                      "Pilot"     James Burrows
# 1             2             2    "The Big Bran Hypothesis"   Mark Cendrowski
# 2             3             3  "The Fuzzy Boots Corollary"   Mark Cendrowski
# 3             4             4   "The Luminous Fish Effect"   Mark Cendrowski
# 4             5             5    "The Hamburger Postulate"  Andrew D. Weyman
# ..          ...           ...                          ...               ...
# 130         131            20      "The Tenure Turbulence"   Mark Cendrowski
# 131         132            21    "The Closure Alternative"   Mark Cendrowski
# 132         133            22      "The Proton Resurgence"   Mark Cendrowski
# 133         134            23   "The Love Spell Potential"      Anthony Rich
# 134         135            24    "The Bon Voyage Reaction"   Mark Cendrowski
#
# ...

# %%
#repeating same steps for season7
s7=data[7]
s7["U.S. viewers(millions)"]=s7["U.S. viewers(millions)"].str.slice(start=0,stop=4)
s7["U.S. viewers(millions)"] = s7["U.S. viewers(millions)"].astype("float")
s7["Original air date"] = pd.to_datetime(s7["Original air date"])
s7["Season"]=7
final=final.append(s7,ignore_index=True)
final
# Out:
#      No.overall  No. inseason                                 Title  \
# 0             1             1                               "Pilot"
# 1             2             2             "The Big Bran Hypothesis"
# 2             3             3           "The Fuzzy Boots Corollary"
# 3             4             4            "The Luminous Fish Effect"
# 4             5             5             "The Hamburger Postulate"
# ..          ...           ...                                   ...
# 154         155            20         "The Relationship Diremption"
# 155         156            21  "The Anything Can Happen Recurrence"
# 156         157            22       "The Proton Transmogrification"
# 157         158            23             "The Gorilla Dissolution"
# 158         159            24           "The Status Quo Combustion"
#
#           Directed by                                         Written by  \
# 0       James Burrows                           Chuck Lorre & Bill Prady
# ...

# %%
#repeating same steps for season 8
s8=data[8]
s8["U.S. viewers(millions)"]=s8["U.S. viewers(millions)"].str.slice(start=0,stop=4)
s8["U.S. viewers(millions)"] = s8["U.S. viewers(millions)"].astype("float")
s8["Original air date"] = pd.to_datetime(s8["Original air date"])
s8["Season"]=8
final=final.append(s8,ignore_index=True)
final
# Out:
#      No.overall  No. inseason                               Title  \
# 0             1             1                             "Pilot"
# 1             2             2           "The Big Bran Hypothesis"
# 2             3             3         "The Fuzzy Boots Corollary"
# 3             4             4          "The Luminous Fish Effect"
# 4             5             5           "The Hamburger Postulate"
# ..          ...           ...                                 ...
# 178         179            20  "The Fortification Implementation"
# 179         180            21   "The Communication Deterioration"
# 180         181            22       "The Graduation Transmission"
# 181         182            23           "The Maternal Combustion"
# 182         183            24      "The Commitment Determination"
#
#           Directed by                                         Written by  \
# 0       James Burrows                           Chuck Lorre & Bill Prady
# ...

# %%
#repeating same steps for season 9
s9=data[9]
s9["U.S. viewers(millions)"]=s9["U.S. viewers(millions)"].str.slice(start=0,stop=4)
s9["U.S. viewers(millions)"] = s9["U.S. viewers(millions)"].astype("float")
s9["Original air date"] = pd.to_datetime(s9["Original air date"])
s9["Season"]=9
final=final.append(s9,ignore_index=True)
final
# Out:
#      No.overall  No. inseason                             Title  \
# 0             1             1                           "Pilot"
# 1             2             2         "The Big Bran Hypothesis"
# 2             3             3       "The Fuzzy Boots Corollary"
# 3             4             4        "The Luminous Fish Effect"
# 4             5             5         "The Hamburger Postulate"
# ..          ...           ...                               ...
# 202         203            20      "The Big Bear Precipitation"
# 203         204            21    "The Viewing Party Combustion"
# 204         205            22    "The Fermentation Bifurcation"
# 205         206            23  "The Line Substitution Solution"
# 206         207            24     "The Convergence Convergence"
#
#           Directed by                                         Written by  \
# 0       James Burrows                           Chuck Lorre & Bill Prady
# ...

# %%
#repeating same steps for season 10
s10=data[10]
s10["U.S. viewers(millions)"]=s10["U.S. viewers(millions)"].str.slice(start=0,stop=4)
s10["U.S. viewers(millions)"] = s10["U.S. viewers(millions)"].astype("float")
s10["Original air date"] = pd.to_datetime(s10["Original air date"])
s10["Season"]=10
final=final.append(s10,ignore_index=True)
final
# Out:
#      No.overall  No. inseason                           Title  \
# 0             1             1                         "Pilot"
# 1             2             2       "The Big Bran Hypothesis"
# 2             3             3     "The Fuzzy Boots Corollary"
# 3             4             4      "The Luminous Fish Effect"
# 4             5             5       "The Hamburger Postulate"
# ..          ...           ...                             ...
# 226         227            20  "The Recollection Dissipation"
# 227         228            21      "The Separation Agitation"
# 228         229            22    "The Cognition Regeneration"
# 229         230            23       "The Gyroscopic Collapse"
# 230         231            24  "The Long Distance Dissonance"
#
#           Directed by                                         Written by  \
# 0       James Burrows                           Chuck Lorre & Bill Prady
# ...

# %%
#repeating same steps for season 11
s11=data[11]
s11["U.S. viewers(millions)"]=s11["U.S. viewers(millions)"].str.slice(start=0,stop=4)
s11["U.S. viewers(millions)"] = s11["U.S. viewers(millions)"].astype("float")
s11["Original air date"] = pd.to_datetime(s11["Original air date"])
s11["Season"]=11
final=final.append(s11,ignore_index=True)
final
# Out:
#      No.overall  No. inseason                         Title       Directed by  \
# 0             1             1                       "Pilot"     James Burrows
# 1             2             2     "The Big Bran Hypothesis"   Mark Cendrowski
# 2             3             3   "The Fuzzy Boots Corollary"   Mark Cendrowski
# 3             4             4    "The Luminous Fish Effect"   Mark Cendrowski
# 4             5             5     "The Hamburger Postulate"  Andrew D. Weyman
# ..          ...           ...                           ...               ...
# 250         251            20     "The Reclusive Potential"   Mark Cendrowski
# 251         252            21      "The Comet Polarization"   Mark Cendrowski
# 252         253            22  "The Monetary Insufficiency"       Nikki Lorre
# 253         254            23     "The Sibling Realignment"   Mark Cendrowski
# 254         255            24       "The Bow Tie Asymmetry"   Mark Cendrowski
#
# ...

# %%
#repeating same steps for season 12
s12=data[12]
s12["U.S. viewers(millions)"]=s12["U.S. viewers(millions)"].str.slice(start=0,stop=4)
s12["U.S. viewers(millions)"] = s12["U.S. viewers(millions)"].astype("float")
s12["Original air date"] = pd.to_datetime(s12["Original air date"])
s12["Season"]=12
final=final.append(s12,ignore_index=True)
final
# Out:
#      No.overall  No. inseason                         Title       Directed by  \
# 0             1             1                       "Pilot"     James Burrows
# 1             2             2     "The Big Bran Hypothesis"   Mark Cendrowski
# 2             3             3   "The Fuzzy Boots Corollary"   Mark Cendrowski
# 3             4             4    "The Luminous Fish Effect"   Mark Cendrowski
# 4             5             5     "The Hamburger Postulate"  Andrew D. Weyman
# ..          ...           ...                           ...               ...
# 274         275            20  "The Decision Reverberation"   Mark Cendrowski
# 275         276            21       "The Plagiarism Schism"       Nikki Lorre
# 276         277            22     "The Maternal Conclusion"      Kristy Cecil
# 277         278            23         "The Change Constant"   Mark Cendrowski
# 278         279            24      "The Stockholm Syndrome"   Mark Cendrowski
#
# ...

# %%
final.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 279 entries, 0 to 278
# Data columns (total 9 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   No.overall              279 non-null    int64
#  1   No. inseason            279 non-null    int64
#  2   Title                   279 non-null    object
#  3   Directed by             279 non-null    object
#  4   Written by              279 non-null    object
#  5   Original air date       279 non-null    datetime64[ns]
#  6   Prod.code               279 non-null    object
#  7   U.S. viewers(millions)  279 non-null    float64
#  8   Season                  279 non-null    int64
# dtypes: datetime64[ns](1), float64(1), int64(3), object(4)
# memory usage: 19.7+ KB

# %%
final
# Out:
#      No.overall  No. inseason                         Title       Directed by  \
# 0             1             1                       "Pilot"     James Burrows
# 1             2             2     "The Big Bran Hypothesis"   Mark Cendrowski
# 2             3             3   "The Fuzzy Boots Corollary"   Mark Cendrowski
# 3             4             4    "The Luminous Fish Effect"   Mark Cendrowski
# 4             5             5     "The Hamburger Postulate"  Andrew D. Weyman
# ..          ...           ...                           ...               ...
# 274         275            20  "The Decision Reverberation"   Mark Cendrowski
# 275         276            21       "The Plagiarism Schism"       Nikki Lorre
# 276         277            22     "The Maternal Conclusion"      Kristy Cecil
# 277         278            23         "The Change Constant"   Mark Cendrowski
# 278         279            24      "The Stockholm Syndrome"   Mark Cendrowski
#
# ...

# %%
final.to_csv("dataset.csv")
